# %% [markdown]
# <a href="https://colab.research.google.com/github/Socio-Crypto/MarginFi-TVL-Growth/blob/main/marginifi_growth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MarginFi: The Fastest Growing DeFi Platform
#
# [MarginFi](https://app.marginfi.com/) is a decentralized lending and borrowing protocol built on Solana. In early July, MarginFi introduced its [mrgn points mechanism](https://twitter.com/marginfi/status/1675863618666270722), marking a pivotal moment for the project.
#
# Since the introduction of MRGN points, the platform has witnessed one of the most rapid growth rates within its niche.
#
# This analytics dashboard uses [DefiLlama's API](https://defillama.com/docs/api) to compare the evolution and percentage growth in TVL of MarginFi with other top lending protocols on Solana (Solend, Port Finance, Larix, Mango Markets, and Apricot Finance) from July 1, 2023 to October 1, 2023.

# %%
import requests
import plotly.express as px
import pandas as pd
import datetime

platforms = ['Solend', 'marginfi-Lending', 'Port-Finance', 'Larix', 'Mango-Markets', 'Apricot-Finance']

platform_data = {}

for platform in platforms:
    url = f'https://api.llama.fi/protocol/{platform}'
    response = requests.get(url)
    data = response.json()
    platform_data[platform] = data['chainTvls']['Solana']['tvl']

df = pd.DataFrame()

# Loop through the platforms
for platform, data in platform_data.items():
    df_platform = pd.DataFrame(data)
    df_platform['Platform'] = platform
    df = pd.concat([df, df_platform], ignore_index=True)

# convert date format and filter date
df['date'] = pd.to_datetime(df['date'], unit='s')
start_date = pd.to_datetime('2023-07-01')
end_date = pd.to_datetime(datetime.date.today())
filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]


fig = px.line(filtered_df, x='date', y='totalLiquidityUSD', color='Platform', labels={'date': 'Date', 'totalLiquidityUSD': 'Total Liquidity (USD)'})
fig.update_layout(title='Total Liquidity Over Time for Different Lending Platforms')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b045e9f5-2e20-4d2b-897c-6e5f452c9458" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b045e9f5-2e20-4d2b-897c-6e5f452c9458")) {                    Plotly.newPlot(                        "b045e9f5-2e20-4d2b-897c-6e5f452c9458",                        [{"hovertemplate":"Platform=Solend\u003cbr\u003eDate=%{x}\u003cbr\u003eTotal Liquidity (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solend","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Solend","orientation":"v","showlegend":true,"x":["2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-20T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00","2023-08-24T00:00:00","2023-08-25T00:00:00","2023-08-26T00:00:00","2023-08-27T00:00:00","2023-08-28T00:00:00","2023-08-29T00:00:00","2023-08-30T00:00:00","2023-08-31T00:00:00","2023-09-01T00:00:00","2023-09-02T00:00:00","2023-09-03T00:00:00","2023-09-04T00:00:00","2023-09-05T00:00:00","2023-09-06T00:00:00","2023-09-07T00:00:00","2023-09-08T00:00:00","2023-09-09T00:00:00","2023-09-10T00:00:00","2023-09-11T00:00:00","2023-09-12T00:00:00","2023-09-13T00:00:00","2023-09-14T00:00:00","2023-09-15T00:00:00","2023-09-16T00:00:00","2023-09-17T00:00:00","2023-09-18T00:00:00","2023-09-19T00:00:00","2023-09-20T00:00:00","2023-09-21T00:00:00","2023-09-22T00:00:00","2023-09-23T00:00:00","2023-09-24T00:00:00","2023-09-25T00:00:00","2023-09-26T00:00:00","2023-09-27T00:00:00","2023-09-28T00:00:00","2023-09-29T00:00:00","2023-09-30T00:00:00","2023-10-01T00:00:00","2023-10-02T00:00:00","2023-10-03T00:00:00","2023-10-04T00:00:00","2023-10-05T00:00:00","2023-10-06T00:00:00"],"xaxis":"x","y":[36205101.81127,36276092.90862,37010221.4715,37074756.56614,37107484.67068,37872713.70472,38328569.4229,40668025.32907,42369664.6607,41313857.86645,41630578.0281,43857416.09084,42993655.95663,54234361.68936,51420171.6599,51545995.5015,51927946.15169,50615655.62644,49185458.98343,49801800.49647,48176059.86364,49146284.68379,46886034.85941,47789996.3115,45502701.54337,45518829.95806,48522812.55218,48843318.09202,48496717.20081,49041644.85885,47901038.26413,46821463.72703,46497001.85089,45772983.59597,45481148.98394,45524253.08784,45841798.73936,46073705.07979,46363658.39392,47989050.90575,48818544.5296,50460472.60531,50554729.16444,51546617.62249,50557972.30048,52259620.41103,49705350.35488,48610338.9474,47071569.8862,46303782.10658,46795295.43567,46836305.36473,46071958.52465,43979253.13019,47771373.35424,46261821.60758,45756342.74851,45361645.11516,46537472.4165,45880689.05544,48313322.28229,46437505.36803,45061111.2916,44332976.75573,44731539.9 ...

# %%
pivot_df = filtered_df.pivot(index='date', columns='Platform', values='totalLiquidityUSD')


start_date = pd.to_datetime('2023-07-01')
end_date = pd.to_datetime('2023-10-01')
percent_change = (pivot_df.loc[end_date] - pivot_df.loc[start_date]) / pivot_df.loc[start_date] * 100
#print(percent_change)

series = pd.Series(percent_change, name='tvl')
df2 = pd.DataFrame({'platform': series.index, 'tvl': series.values})
print(df2)

fig = px.bar(df2, x='platform', y='tvl',color='platform', labels={'Platform': 'Platform', 'tvl': 'Percent Change (%)'})
fig.update_layout(title='Percent Change in TVL from July 1, 2023, to October 1, 2023')
fig.show()
# Out:
#            platform         tvl
# 0   Apricot-Finance    5.228878
# 1             Larix  -17.847133
# 2     Mango-Markets   83.205713
# 3      Port-Finance    6.325583
# 4            Solend   31.342353
# 5  marginfi-Lending  643.613182
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="17045834-e732-481e-b888-0000669bb431" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17045834-e732-481e-b888-0000669bb431")) {                    Plotly.newPlot(                        "17045834-e732-481e-b888-0000669bb431",                        [{"alignmentgroup":"True","hovertemplate":"platform=%{x}\u003cbr\u003ePercent Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apricot-Finance","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Apricot-Finance","offsetgroup":"Apricot-Finance","orientation":"v","showlegend":true,"textposition":"auto","x":["Apricot-Finance"],"xaxis":"x","y":[5.228878432454778],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"platform=%{x}\u003cbr\u003ePercent Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Larix","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Larix","offsetgroup":"Larix","orientation":"v","showlegend":true,"textposition":"auto","x":["Larix"],"xaxis":"x","y":[-17.847132825700292],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"platform=%{x}\u003cbr\u003ePercent Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mango-Markets","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mango-Markets","offsetgroup":"Mango-Markets","orientation":"v","showlegend":true,"textposition":"auto","x":["Mango-Markets"],"xaxis":"x","y":[83.205713264596],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"platform=%{x}\u003cbr\u003ePercent Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Port-Finance","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Port-Finance","offsetgroup":"Port-Finance","orientation":"v","showlegend":true,"textposition":"auto","x":["Port-Finance"],"xaxis":"x","y":[6.3255829687838885],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"platform=%{x}\u003cbr\u003ePercent Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solend","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Solend","offsetgroup":"Solend","orientation":"v","showlegend":true,"textposition":"auto","x":["Solend"],"xaxis":"x","y":[31.34235285682228],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"platform=%{x}\u003cbr\u003ePercent Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"marginfi-Lending","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"marginfi-Lending","offsetgroup":"marginfi-Lending","orientation":"v","showlegend":true,"textposition":"auto","x":["marginfi-Lending"],"xaxis":"x","y":[643.6131821971886],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#460 ...
